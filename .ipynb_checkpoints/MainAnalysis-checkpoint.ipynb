# %% [markdown]
# # All imports

# %%
import os,sys,string, time
import pickle
print(sys.path)
print (sys.version)
import ROOT
import seaborn as sns

import Neutrino_functions

from matplotlib.lines import Line2D
from math import *
from ROOT import gPad, TTree, TObject, TFile, gDirectory, TH1D, TH2D, TH3D, TCanvas, gROOT, TGaxis, gStyle, TColor, TLegend, THStack, TChain, TLatex, TText, TCollection, kRed, kBlue
from array import array
import math
import matplotlib.pyplot as plt
import awkward 
import plotly.express as px
import numpy as np
import matplotlib.ticker as tck
from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show    
import uproot3
import matplotlib.cm as cm
import matplotlib.mlab as mlab

import pandas as pd

from root_pandas import read_root
from platform import python_version

import scipy as sci
from scipy import stats
import scipy.optimize as op
# Out:
# ['/uboone/app/users/finnerud/python_scripts', '/cvmfs/uboone.opensciencegrid.org/products/ubutil/v09_32_00/slf7.x86_64.e20.prof/lib', '/cvmfs/uboone.opensciencegrid.org/products/ubutil/v09_32_00/python', '/cvmfs/uboone.opensciencegrid.org/products/ubutil/v09_32_00/bin', '/cvmfs/larsoft.opensciencegrid.org/products/larbatch/v01_56_02/python', '/cvmfs/larsoft.opensciencegrid.org/products/larbatch/v01_56_02/bin', '/cvmfs/fermilab.opensciencegrid.org/products/common/prd/sam_web_client/v3_0/NULL/python', '/cvmfs/fermilab.opensciencegrid.org/products/common/prd/python_future_six_request/v1_3_1/Linux64bit-3-10-2-17-python3-9', '/cvmfs/fermilab.opensciencegrid.org/products/common/prd/jobsub_client/v1_3_5/NULL', '/cvmfs/uboone.opensciencegrid.org/products/swtrigger/v02_03_00d/Linux64bit+3.10-2.17/python', '/cvmfs/uboone.opensciencegrid.org/products/larlite/v06_71_00d/Linux64bit+3.10-2.17-e20-prof/python', '/cvmfs/uboone.opensciencegrid.org/products/larcv/v06_71_00d/Linux64bit+3.10-2.17-e20-prof/python', '/cvmfs/larsoft.opensciencegrid.org/products/larsoft/v09_36_00/bin/python', '/cvmfs/larsoft.opensciencegrid.org/products/libtorch/v1_6_0d/Linux64bit+3.10-2.17-e20/lib', '/cvmfs/larsoft.opensciencegrid.org/products/ifdhc/v2_5_16/Linux64bit+3.10-2.17-e20-p392-prof/lib/python', '', '/cvmfs/larsoft.opensciencegrid.org/products/pythia8/v8_3_05/Linux64bit+3.10-2.17-e20-p392-prof/lib/python3.9/site-packages', '/cvmfs/larsoft.opensciencegrid.org/products/hepmc3/v3_2_3/Linux64bit+3.10-2.17-e20-p392-prof/lib/python3.9/site-packages', '/cvmfs/larsoft.opensciencegrid.org/products/lhapdf/v6_3_0/Linux64bit+3.10-2.17-e20-p392-prof/lib/python3.9/site-packages', '/cvmfs/larsoft.opensciencegrid.org/products/xrootd/v5_1_0/Linux64bit+3.10-2.17-e20-p392-prof/lib', '/cvmfs/larsoft.opensciencegrid.org/products/postgresql/v13_2/Linux64bit+3.10-2.17-p392/lib/python3.9/site-packages', '/cvmfs/larsoft.opensciencegrid.org/products/numpy/v1_20_1/Linux64bit+3.10-2.17-e20-p392/lib/python3.9/site-packages', '/cvmfs/larsoft.opensciencegrid.org/products/root/v6_22_08d/Linux64bit+3.10-2.17-e20-p392-prof/lib', '/cvmfs/larsoft.opensciencegrid.org/products/python/v3_9_2/Linux64bit+3.10-2.17/lib/python39.zip', '/cvmfs/larsoft.opensciencegrid.org/products/python/v3_9_2/Linux64bit+3.10-2.17/lib/python3.9', '/cvmfs/larsoft.opensciencegrid.org/products/python/v3_9_2/Linux64bit+3.10-2.17/lib/python3.9/lib-dynload', '/nashome/f/finnerud/.local/lib/python3.9/site-packages', '/cvmfs/larsoft.opensciencegrid.org/products/python/v3_9_2/Linux64bit+3.10-2.17/lib/python3.9/site-packages', '/nashome/f/finnerud/.local/lib/python3.9/site-packages/IPython/extensions', '/nashome/f/finnerud/.ipython']
# 3.9.2 (default, Mar  7 2021, 07:53:23)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-44)]
# Welcome to JupyROOT 6.22/08

# %% [markdown]
# # Opening the MC and data frames

# %%
#MC
MC_file = 'Files/MC_EXT_flattened_1_correct.pkl'
#Data
data_file = 'Files/data_flattened_1_correct.pkl'

MC_EXT = pd.read_pickle(MC_file)
data = pd.read_pickle(data_file)

# %% [markdown]
# # You can display the dataframe by uncommenting these lines and running the cell

# %%
#Uncomment these lines to display the dataframes
#pd.set_option('display.max_columns', 100)
#data.head(100)
# Out:
#      level_0  index  entry  _closestNuCosmicDist  crtveto pfp_generation_v  \
# 2          0      0      0             48.170196        0                2
# 5          9      3      1            177.083498        0                2
# 7         31     11      4             36.361293        0                2
# 9         35     13      5            127.613429        0                2
# 11        40     16      7            101.562292        0                2
# ..       ...    ...    ...                   ...      ...              ...
# 187      990    374    185            136.537142        0                2
# 189      992    376    187            104.816733        0                2
# 191      996    378    188            193.341157        0                2
# 194     1004    382    190            198.239678        0                2
# 195     1013    385    191             78.622574        0                2
#
#                        trk_energy_proton_v   trk_len_v trk_distance_v  \
# 2     [0.79490316, 0.1726535, 0.054027334]  230.178085       0.289455
# 5    [0.65581083, 0.06843351, 0.047760192]  174.338699       0.057629
# 7                 [1.3871299, 0.071979366]  493.096283       0.465464
# 9                 [0.6736586, 0.121208936]  181.327194       0.272344
# 11                [0.10761618, 0.11383914]    8.869122     265.905823
# ..                                     ...         ...            ...
# 187                           [0.44441244]   95.834389       0.171345
# 189               [0.27430174, 0.19331864]   43.747456       0.220283
# 191              [0.97959816, 0.054678004]  308.670349      39.519314
# 194   [0.61713594, 0.17537181, 0.11408269]  159.382202       0.386907
# 195                           [0.68458325]  185.631348       0.143909
#
#      category  topological_score trk_sce_end_z_v trk_sce_end_y_v  \
# 2           0           0.932121      662.713745      -10.419758
# 5           0           0.588847      978.765259        9.115969
# 7           0           0.983048      865.795166      -56.678547
# 9           0           0.021950      264.979065       92.158607
# 11          0           0.036152       110.97657       81.228905
# ..        ...                ...             ...             ...
# 187         0           0.014041      992.488831       63.325794
# 189         0           0.056457       120.68161      107.048485
# 191         0           0.065181      228.330078      115.467026
# 194         0           0.086390      109.206863      121.252777
# 195         0           0.003791       623.44989      -39.468853
#
#     trk_sce_end_x_v trk_score_v                    trk_llr_pid_score_v  \
# 2          0.564317    0.430468    [0.9817983, 0.72224534, 0.16720754]
# 5        153.437668    0.951437  [0.97021365, -0.2914539, -0.15800577]
# 7         80.313004    0.972104              [0.99040306, -0.27410355]
# 9        255.202988    0.791141               [0.9584787, -0.28761604]
# 11          30.3652    0.940867              [0.13313442, -0.17672117]
# ..              ...         ...                                    ...
# 187       32.338531    0.996051                           [0.95418024]
# 189      181.809494     0.72042                [0.8608611, 0.41503385]
# 191      213.566422    0.775797                 [0.97826225, 0.137265]
# 194      212.255325    0.800888    [0.9554505, 0.62891024, 0.36015007]
# 195       69.345573         1.0                           [0.97262424]
#
#     trk_sce_start_z_v trk_sce_start_y_v trk_sce_start_x_v  reco_nu_vtx_sce_x  \
# 2          443.558472        -71.411057          32.10228          32.137272
# 5          852.828674        -36.029785         42.856102          42.869896
# 7          408.639801         96.316406        141.032898         141.039246
# 9          230.559982        -81.870941         221.46637         221.349503
# 11         114.274597         86.827835         36.310745         170.431870
# ..                ...               ...               ...                ...
# 187        914.494324        117.237526         20.015165          19.997118
# 189        124.256142          64.65448        171.805038         171.701202
# 191         -1.218884         -73.84523        237.692612         238.109894
# 194         69.887123        -25.293329        206.063477         206.100998
# 195        536.305542        108.414757          0.680147           0.602751
#
#      reco_nu_vtx_sce_y  reco_nu_vtx_sce_z  nslice  trk_energy_tot
# 2           -71.675980         443.439148       1        1.021584
# 5           -35.978130         852.848938       1        0.772005
# 7            96.385994         408.178772       1        1.459109
# 9           -81.868439         230.311829       1        0.794868
# 11           59.736755         340.503021       1        0.221455
# ..                 ...                ...     ...             ...
# 187         117.178589         914.334290       1        0.444412
# 189          64.637505         124.062309       1        0.467620
# 191        -114.682144           2.399803       1        1.034276
# 194         -25.427021          69.508934       1        0.906590
# 195         108.305023         536.355957       1        0.684583
#
# [100 rows x 24 columns]

# %% [markdown]
# # This command when ran shows you the different inputs you can give the function

# %%
#This command shows what input you should give the plotting function. The inputs with =None can be left out when calling the function
help(Neutrino_functions.histogram_plot)
# Out:
# Help on function histogram_plot in module ipynb.fs.full.Neutrino_functions:
#
# histogram_plot(MC_frame, variable, bins, name, scaling, plot_data=None, logscale=None, dataFrame=None)

# %% [markdown]
# # Make your selections here

# %%
def Selections(frame):

    trk_start_x_v = frame['trk_sce_start_x_v']
    trk_start_y_v = frame['trk_sce_start_y_v']
    trk_start_z_v = frame['trk_sce_start_z_v']
    trk_end_x_v = frame['trk_sce_end_x_v']
    trk_end_y_v = frame['trk_sce_end_y_v']
    trk_end_z_v = frame['trk_sce_end_z_v'] 
    reco_x = frame['reco_nu_vtx_sce_x']
    reco_y = frame['reco_nu_vtx_sce_y']
    reco_z = frame['reco_nu_vtx_sce_z']
    topological = frame['topological_score']
    trk_score_v = frame['trk_score_v']
    trk_dis_v = frame['trk_distance_v']
    trk_len_v = frame['trk_len_v']

   
    
    
    selection =  (trk_len_v > -1000) & (trk_len_v < 1000) 
    frame = frame[selection]
    
    return frame

# %% [markdown]
# # Calls the selection function on the dataframes

# %%
MC_EXT = Selections(MC_EXT)
data_frame = Selections(data)

# %% [markdown]
# # Plot the energy spectrums here and normalise
